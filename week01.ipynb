# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterShiaush/ColabRepo/blob/main/week01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **第一週：打底與環境建置 (Foundations)**

# %% [markdown]
# ## **第一節 (W1-S1)：指尖飛舞與 Python 初見**
#
# ### **0-15 min: 英打特訓 (TypingClub)**
# * 活動：進入 [TypingClub](https://www.typingclub.com/)。
# * 目標：不求快，求「指法正確」。自然組學生代碼量大，基礎手位決定未來的開發速度。
#
#
# ### **15-35 min: Colab 第一次接觸**
# * 介紹 Google Colab (雲端運算，不需安裝環境)。
# * **Python 觀念：變數 (Variable)**。
# * 實作：定義變數 `student_id = "91001"`, `score = 100`。
#
#
# ### **35-45 min: OpenCV 快速展示**
# * 以Python程式碼，在 Colab 秀出一張圖片

# %% [markdown]
# ### **0-15 min: 英打特訓 (TypingClub)**
#
# * 活動：進入 [TypingClub](https://www.typingclub.com/)。
# * 目標：不求快，求「指法正確」。自然組學生代碼量大，基礎手位決定未來的開發速度。

# %% [markdown]
# 玩10分鐘，
#
# 不要快，**正確為上**
#
# 但求「指法正確」。

# %% [markdown]
# ### **15-35 min: Colab 第一次接觸**
# * 介紹 Google Colab (雲端運算，不需安裝環境)。
# * **請登入[Google Colab](https://colab.research.google.com/?hl=zh-tw)**

# %% [markdown]
# * Python 觀念：變數 (Variable)。
# * 實作：定義變數 `student_id = "91001"`, `score = 100`。

# %%
student_id = "91001"
score = 100
print(student_id, score)
# Out:
# 91001 100

# %%
學生學號 = "91001"
分數 = 100
print(學生學號, 分數)
# Out:
# 91001 100

# %%
x = "91001"
y = 100
print(x, y)
# Out:
# 91001 100

# %%
iii = "91001"
sss = 100
print(iii, sss)
# Out:
# 91001 100

# %% [markdown]
# ---
#
# **`請比較何者為佳?為何較佳?`**
#
# **1**.
# ```
# student_id = "91001"
# score = 10
# ```
# **2**.
# ```
# studentID = "91001"
# score = 100
# ```
# **3**.
# ```
# 學生學號 = "91001"
# 分數 = 100
# ```
# **4**.
# ```
# x = "91001"
# y = 100
# ```

# %% [markdown]
# **Python 變數名稱**，只能包含字母 **（A-Z, a-z）**、數字 **（0-9）** 和底線 **（_）**，且**不能以數字開頭**。

# %% [markdown]
# **不符合規定（非法） 的變數名稱分類與範例：**
# 1. 不能以數字開頭，變數名稱的第一個字元必須是字母（A-Z, a-z）或底線（_）。
#  * ❌ 錯誤範例： **1**st_player, **7**days, **2**026_data
#  * ✅ 正確寫法： player_1st, days_7, data_2024
#
# 2. 不能包含空格，變數必須是一個連續的字串。
#  * ❌ 錯誤範例： user name, total price, my variable
#  * ✅ 正確寫法： user_name, total_price (建議使用底線隔開)
#
# 3. 不能使用保留字(Keywords)，Python 有一些內建具備特殊功能的關鍵字，不能被當作變數名稱。
#  * ❌ 錯誤範例： if, else, while, for, def, class, import, True, False, None, and, or
#
# 4. 提示： 如果你在編輯器中看到某個詞變色了（通常是紫色或藍色），那很可能就是保留字。
# 5. 不能包含特殊符號
# 除了底線 (_) 之外，其他的標點符號或特殊字元都是不允許的。
#  * ❌ 錯誤範例： user-name (被誤認成減法),
#  * ❌ price$
#  * ❌ email@address
#  * ❌ status!
#  * ✅ 正確寫法： user_name, price_usd

# %% [markdown]
# **為什麼錯？**
#  * 5level
#  * my dog
#  * try
#  * user-id

# %% [markdown]
# **Python 是區分大小寫 (Case-sensitive) 的。**
#  * **N**ame
#  * **n**ame
#
# 雖然 **N**ame 和 **n**ame 都是合法的，但它們會被視為兩個完全不同的變數。

# %% [markdown]
# ### **35-45 min: OpenCV 快速展示**

# %% [markdown]
# *  以Python程式碼，在 Colab 秀出一張圖片

# %%
# 第 1 行：從網路下載一張圖片 (這是 Linux 指令) or 公車與行人 bus.jpg
# !wget -q -O demo.jpg https://raw.githubusercontent.com/ultralytics/yolov5/master/data/images/zidane.jpg

# 第 2 行：呼叫 OpenCV 和 Colab 專用的顯示工具
import cv2
from google.colab.patches import cv2_imshow

# 第 3 行：讀取圖片 -> 秀出來！
cv2_imshow(cv2.imread('demo.jpg'))

# %% [markdown]
# ## **第二節 (W1-S2)：互動與雲端儲存**
#
# ### **0-15 min: Python 觀念 - 輸入 (Input) 與輸出**
# * 實作：寫一個簡單程式 `myName = input("輸入你的名字: ")`，然後印出歡迎詞。
# * 觀念：資料型態 (字串 vs 數字) 的簡單區別。
#
#
# ### **15-40 min: GitHub 連結**
# * 註冊/登入 GitHub。
# * **關鍵操作**：在 Colab 中 "File" -> "Save a copy in GitHub"。
# * **作業**：將剛剛寫的 Input 練習存入 GitHub Repository，並繳交連結。
#
#
# ### **40-45 min: 預告**
# * 下週將開始處理真正的圖像。

# %% [markdown]
# ### **0-15 min: Python 觀念 - 輸入 (Input) 與輸出**

# %% [markdown]
# *   實作：寫一個簡單程式 myName = input("輸入你的名字: ")，然後印出歡迎詞。

# %%
name = input("輸入你的名字: ")
print(f"歡迎你, {name}!")

# %% [markdown]
# *   觀念：資料型態 (字串 vs 數字) 的簡單區別。

# %% [markdown]
# Python 會自動判斷變數的資料型態，但了解它們的區別很重要。
#
# *   **字串 (String)**：用於儲存文字資料，通常用單引號 `'` 或雙引號 `"` 括起來。
#     *   **範例**：`"哈囉世界"`, `'Python 真有趣'`, `name` (來自你的輸入)
#     *   **特性**：不能直接進行數學運算。
#
# *   **數字 (Number)**：用於儲存數值資料，主要分為兩種：
#     *   **整數 (Integer)**：沒有小數點的數字。
#         *   **範例**：`10`, `-5`, `1000`
#     *   **浮點數 (Float)**：有小數點的數字。
#         *   **範例**：`3.14`, `-0.5`, `99.9`
#     *   **特性**：可以進行各種數學運算 (加、減、乘、除等)。

# %% [markdown]
# **比較：**
#
# `"100"` 是一個**字串**，即使它看起來像數字，但它被引號括起來。
# `100` 是一個**數字** (整數)。
#
# 如果你嘗試對字串 `'100'` 和字串 `'200'` 執行加法 `"100" + "200"`，結果會是 `'100200'` (字串連接)，而不是 `300` (數學加法)。
#
# 程式碼如下:

# %%
# 字串連接
string_num1 = "100"
string_num2 = "200"
string_result = string_num1 + string_num2
print(f"字串 '100' + '200' 的結果是: {string_result} (字串連接)")

# 數字加法
int_num1 = 100
int_num2 = 200
int_result = int_num1 + int_num2
print(f"數字 100 + 200 的結果是: {int_result} (數學加法)")

# %% [markdown]
# ### **15-40 min: GitHub 連結**

# %% [markdown]
# *   註冊 GitHub。

# %% [markdown]
# *   登入 GitHub。
# *   左側綠色 Create a repository (創造一個repository 儲存庫，命名: **ColabRepo**)
# *   description: **ColabRepo for me to save Colab file**
# *   Add .gitignore: **Python** (自動排除不必要的暫存檔、環境設定檔或**機密資料
# **)
# *   最下面綠色: **Create repository**

# %% [markdown]
# * **回 Colab **
# * **關鍵操作**：在 Colab 中 "File" -> "Save a copy in GitHub"。
# * **關鍵操作**：在 Colab 中 "檔案" -> "**在 GitHub 中儲存副本**"。(名: **ColabRepo**)
# * **作業**：將剛剛寫的 Input 練習存入 GitHub ColabRepo，並繳交連結。

# %% [markdown]
# * **作業**：將剛剛寫的 Input 練習存入 GitHub ColabRepo，並繳交連結。

# %% [markdown]
# * **40-45 min: 預告**
# * 下週將開始處理真正的圖像。
